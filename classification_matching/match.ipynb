# %%
import pandas
google_api = pandas.read_excel('GOOGLE API BUSSINESS TYPE NAMES.xlsx',header=0,sheet_name = 'Only_matched')
google_api['GOOGLE API ALL BUSINESS TYPE'] = google_api['GOOGLE API ALL BUSINESS TYPE'].str.strip()
google_api['GOOGLE API ALL BUSINESS TYPE'] = google_api['GOOGLE API ALL BUSINESS TYPE'].str.lower()

# %%
armadale = pandas.read_excel('armadale_cleaned.xlsx',header=0)
armadale = pandas.DataFrame(armadale)
business_type = armadale['temp_business_types'].str.split(',', expand=False)


classification  = dict(zip(google_api['GOOGLE API ALL BUSINESS TYPE'], google_api['Classification']))
Category  = dict(zip(google_api['GOOGLE API ALL BUSINESS TYPE'], google_api['Category']))
Category_code  = dict(zip(google_api['GOOGLE API ALL BUSINESS TYPE'], google_api['Category code']))
Sub_category  = dict(zip(google_api['GOOGLE API ALL BUSINESS TYPE'], google_api['Sub-category']))
Sub_category_code  = dict(zip(google_api['GOOGLE API ALL BUSINESS TYPE'], google_api['Sub- category code']))
#Description_and_examples  = dict(zip(google_api['GOOGLE API ALL BUSINESS TYPE'], google_api['Description and examples'])

# %%
classification.keys()
#armadale['temp_business_types'][1]
# Out:
# dict_keys(['airport', 'amusement_park', 'aquarium', 'art_gallery', 'bakery', 'bar', 'beauty_salon', 'bicycle_store', 'book_store', 'bowling_alley', 'bus_station', 'cafe', 'campground', 'casino', 'church', 'city_hall', 'clothing_store', 'convenience_store', 'department_store', 'doctor', 'drugstore', 'electronics_store', 'embassy', 'fire_station', 'florist', 'funeral_home', 'furniture_store', 'gas_station', 'gym', 'hair_care', 'hardware_store', 'health', 'hindu_temple', 'home_goods_store', 'hospital', 'library', 'light_rail_station', 'liquor_store', 'local_government_office', 'lodging', 'meal_delivery', 'meal_takeaway', 'mosque', 'movie_rental', 'movie_theater', 'moving_company', 'museum', 'night_club', 'park', 'patisserie & cafe', 'pet_store', 'premise', 'pharmacy', 'police', 'post_office', 'primary_school', 'restaurant', 'rv_park', 'school', 'secondary_school', 'shoe_store', 'spa', 'stadium', 'storage', 'store', 'subway_station', 'supermarket', 'taxi_stand', 'tourist_attraction', 'train_station', 'transit_station', 'travel_agency', 'university', 'zoo', 'point_of_interest', 'establishment'])

# %%
business_type = armadale['temp_business_types'].copy()

for i in range(len(business_type)):
    matched = []

    for type in business_type[i].split(','):     
        if type.strip() in classification.keys():
            matched.append(type)
            
         
    business_type[i] = matched
 #   armadale['temp_business_types'][i] =armadale['temp_business_types'][i][0]      
#business_type = business_type.str.strip()
#business_type = business_type.str.lower()
#armadale['temp_business_types']
#business_type = armadale['temp_business_types']

# %%
business_type
# Out:
# 0      [primary_school,  school,  point_of_interest, ...
# 1      [secondary_school,  school,  point_of_interest...
# 2      [school,  primary_school,  university,  point_...
# 3           [school,  point_of_interest,  establishment]
# 4      [primary_school,  school,  point_of_interest, ...
#                              ...
# 484         [ point_of_interest,  store,  establishment]
# 485     [restaurant,  point_of_interest,  establishment]
# 486                                            [premise]
# 487                                            [premise]
# 488        [storage,  point_of_interest,  establishment]
# Name: temp_business_types, Length: 489, dtype: object

# %%
for i in range(len(business_type)):

    for k in range(len(business_type[i])) :
        key = business_type[i][k].strip()
        armadale['classification_name'][i]= classification.get(key,0)
        armadale['category_1'][i]= Category.get(key.strip(),0)
        armadale['sub_category_1'][i]= Category_code.get(key.strip(),0)
        armadale['category_2'][i]= Sub_category.get(key.strip(),0)
        armadale['category_3'][i]= Sub_category_code.get(key.strip(),0)

        if classification.get(key,0) != 0:
            break
# Out:
# /var/folders/1_/fcmjcggj0f78hwz7ngj0rxmc0000gn/T/ipykernel_1091/1633938058.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   armadale['classification_name'][i]= classification.get(key,0)
# /var/folders/1_/fcmjcggj0f78hwz7ngj0rxmc0000gn/T/ipykernel_1091/1633938058.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   armadale['category_1'][i]= Category.get(key.strip(),0)
# /var/folders/1_/fcmjcggj0f78hwz7ngj0rxmc0000gn/T/ipykernel_1091/1633938058.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   armadale['sub_category_1'][i]= Category_code.get(key.strip(),0)
# /var/folders/1_/fcmjcggj0f78hwz7ngj0rxmc0000gn/T/ipykernel_1091/1633938058.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   armadale['category_2'][i]= Sub_category.get(key.strip(),0)
# /var/folders/1_/fcmjcggj0f78hwz7ngj0rxmc0000gn/T/ipykernel_1091/1633938058.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   armadale['category_3'][i]= Sub_category_code.get(key.strip(),0)

# %% [markdown]
# RATIO of MATCHED BUSSINESS

# %%
from cmath import nan


matched_num = len(armadale[armadale['classification_name'].isna()])
total = len(armadale['classification_name'])
ratio = round(matched_num/total *100,3)
ratio = 100- ratio
print(str(ratio)  + '%')
# Out:
# 99.182%

# %%
armadale[1:50]
# Out:
#    local_government_area  business_id                    places_id  \
# 1      Armadale, City of          NaN  ChIJXw2JQxaTMioRTcu9c23ef70
# 2      Armadale, City of          NaN  ChIJeZMNGAOTMioRddFiyCjwpZE
# 3      Armadale, City of          NaN  ChIJN9znsoGTMioRdmDxoC8den0
# 4      Armadale, City of          NaN  ChIJCw4NLXyTMioRtk7LjOSi9co
# 5      Armadale, City of          NaN  ChIJsYjgatCUMioRJ_j8t39P5T0
# 6      Armadale, City of          NaN  ChIJkxTSQQuTMioRitETU0LL_SY
# 7      Armadale, City of          NaN  ChIJHRhB3P2TMioRVltHiDWO2xI
# 8      Armadale, City of          NaN  ChIJE5ynLaSUMioRpB7P6Hj7Ilg
# 9      Armadale, City of          NaN  ChIJo0gYiw6TMioR0EbOGqGUXGA
# 10     Armadale, City of          NaN  ChIJscbc9YuUMioR5yb-kUUe320
# 11     Armadale, City of          NaN  ChIJvXXcLL2UMioRu3Pd2Baxi2o
# 12     Armadale, City of          NaN  ChIJ5Vu3UOWUMioRb2Li5M7QXZE
# 13     Armadale, City of          NaN  ChIJ_dg_TpeUMioRqlKPwi25-00
# 14     Armadale, City of          NaN  ChIJoWnLRmuTMioR2ZhQe6Q9XTY
# 19           point_of_interest, school, establishment
# 20  primary_school, school, point_of_interest, est...
# 21  primary_school, school, point_of_interest, est...
# 22  secondary_school, school, point_of_interest, e...
# 23  restaurant, food, point_of_interest, establish...
# 24             food, point_of_interest, establishment
# 25                                            premise
# 26                                            premise
# 27                   point_of_interest, establishment
# 28                   point_of_interest, establishment
# 29                   point_of_interest, establishment
# 30                   point_of_interest, establishment
# 31                   point_of_interest, establishment
# 32    travel_agency, point_of_interest, establishment
# 33                   point_of_interest, establishment
# 34                   point_of_interest, establishment
# 35                   point_of_interest, establishment
# 36           health, point_of_interest, establishment
# 37                   point_of_interest, establishment
# 38    park, premise, point_of_interest, establishment
# 39                   point_of_interest, establishment
# 40                   point_of_interest, establishment
# 41                   point_of_interest, establishment
# 42                                     street_address
# 43                   point_of_interest, establishment
# 44  restaurant, bar, food, point_of_interest, esta...
# 45                   point_of_interest, establishment
# 46                   point_of_interest, establishment
# 47              bar, point_of_interest, establishment
# 48                   point_of_interest, establishment
# 49  book_store, store, point_of_interest, establis...
#
#                    classification_name                category_1  \
# 1                   INSTITUTIONAL FOOD                 Education
# 2                   INSTITUTIONAL FOOD                 Education
# 3                   INSTITUTIONAL FOOD                 Education
# 4                   INSTITUTIONAL FOOD                 Education
# 5                   INSTITUTIONAL FOOD                 Education
# 6                   INSTITUTIONAL FOOD                 Education
# 7                   INSTITUTIONAL FOOD                 Education
# 8                   INSTITUTIONAL FOOD                 Education
# 9                   INSTITUTIONAL FOOD                 Education
# 10             FOOD RETAI,FOOD SERVICE                       NaN
# 11                  INSTITUTIONAL FOOD                 Education
# 12                  INSTITUTIONAL FOOD                 Education
# 13                  INSTITUTIONAL FOOD                 Education
# 14                  INSTITUTIONAL FOOD                 Education
# 15                  INSTITUTIONAL FOOD                 Education
# 16                  INSTITUTIONAL FOOD                 Education
# 17                  INSTITUTIONAL FOOD                 Education
# 18                  INSTITUTIONAL FOOD                 Education
# 19             FOOD RETAI,FOOD SERVICE                       NaN
# 20                  INSTITUTIONAL FOOD                 Education
# 21                  INSTITUTIONAL FOOD                 Education
# 22                  INSTITUTIONAL FOOD                 Education
# 23                        FOOD SERVICE                Restaurant
# 24             FOOD RETAI,FOOD SERVICE                       NaN
# 25                        FOOD SERVICE                       NaN
# 26                        FOOD SERVICE                       NaN
# 27             FOOD RETAI,FOOD SERVICE                       NaN
# 28             FOOD RETAI,FOOD SERVICE                       NaN
# 29             FOOD RETAI,FOOD SERVICE                       NaN
# 30             FOOD RETAI,FOOD SERVICE                       NaN
# 31             FOOD RETAI,FOOD SERVICE                       NaN
# 32  ACCOMMODATION/ RECREATION SERVICES       Entertainment venue
# 33             FOOD RETAI,FOOD SERVICE                       NaN
# 34             FOOD RETAI,FOOD SERVICE                       NaN
# 35             FOOD RETAI,FOOD SERVICE                       NaN
# 36                  INSTITUTIONAL FOOD                       NaN
# 37             FOOD RETAI,FOOD SERVICE                       NaN
# 38  ACCOMMODATION/ RECREATION SERVICES  Health and leisure venue
# 39             FOOD RETAI,FOOD SERVICE                       NaN
# 40             FOOD RETAI,FOOD SERVICE                       NaN
# 41             FOOD RETAI,FOOD SERVICE                       NaN
# 42                                 NaN                       NaN
# 43             FOOD RETAI,FOOD SERVICE                       NaN
# 44                        FOOD SERVICE                Restaurant
# 45             FOOD RETAI,FOOD SERVICE                       NaN
# 46             FOOD RETAI,FOOD SERVICE                       NaN
# 47                        FOOD SERVICE     Licensed liquor venue
# 48             FOOD RETAI,FOOD SERVICE                       NaN
# 49                         FOOD RETAIL            General retail
#
#    sub_category_1            category_2  ...  \
# 1           E6.00           High school  ...
# 2             NaN                   NaN  ...
# 3             NaN                   NaN  ...
# 4           E6.00        Primary school  ...
# 5           E6.00        Primary school  ...
# 6             NaN                   NaN  ...
# 7           E6.00        Primary school  ...
# 8           E6.00        Primary school  ...
# 9           E6.00        Primary school  ...
# 10            NaN                   NaN  ...
# 11          E6.00        Primary school  ...
# 12            NaN                   NaN  ...
# 13          E6.00           High school  ...
# 14          E6.00        Primary school  ...
# 15          E6.00        Primary school  ...
# 16          E6.00        Primary school  ...
# 17            NaN                   NaN  ...
# 18            NaN                   NaN  ...
# 19            NaN                   NaN  ...
# 20          E6.00        Primary school  ...
# 21          E6.00        Primary school  ...
# 22          E6.00           High school  ...
# 23            NaN                   NaN  ...
# 24            NaN                   NaN  ...
# 25            NaN                   NaN  ...
# 26            NaN                   NaN  ...
# 27            NaN                   NaN  ...
# 28            NaN                   NaN  ...
# 29            NaN                   NaN  ...
# 30            NaN                   NaN  ...
# 31            NaN                   NaN  ...
# 32          F1.00                   NaN  ...
# 33            NaN                   NaN  ...
# 34            NaN                   NaN  ...
# 35            NaN                   NaN  ...
# 36            NaN                   NaN  ...
# 37            NaN                   NaN  ...
# 38          F2.00  Sports/exercise/play  ...
# 39            NaN                   NaN  ...
# 40            NaN                   NaN  ...
# 41            NaN                   NaN  ...
# 42            NaN                   NaN  ...
# 43            NaN                   NaN  ...
# 44            NaN                   NaN  ...
# 45            NaN                   NaN  ...
# 46            NaN                   NaN  ...
# 47          B4.00           Serves food  ...
# 48            NaN                   NaN  ...
# 49         A14.00                   NaN  ...
#
#                  original_lga_provided_address  \
# 1   169 South Western Highway ARMADALE WA 6112
# 2                10 Ninth Road HILBERT WA 6112
# 3       39 Seville Drive SEVILLE GROVE WA 6112
# 4          40 Braemore Street ARMADALE WA 6112
# 5              1 Butler Pass KELMSCOTT WA 6111
# 6            150 Forrest Road ARMADALE WA 6112
# 7            Broome Street FORRESTDALE WA 6112
# 8        15 Arbuthnot Street KELMSCOTT WA 6111
# 9               Tijuana Road BROOKDALE WA 6112
# 10          9 Grovelands Drive CAMILLO WA 6111
# 11         18 Orlando Street KELMSCOTT WA 6111
# 12                 Centre Road CAMILLO WA 6111
# 13           50 Third Avenue KELMSCOTT WA 6111
# 14         11 Lathwell Street ARMADALE WA 6112
# 8         NaN    NaN                         https://www.gsk.wa.edu.au/
# 9         NaN    NaN                  https://www.gwynneparkesc.org.au/
# 10        NaN    NaN  https://schoolmatesoshc.com.au/?utm_source=goo...
# 11        NaN    NaN       http://www.kelmscottprimaryschool.wa.edu.au/
# 12        NaN    NaN                        http://www.jwacs.wa.edu.au/
# 13        NaN    NaN                         http://www.kshs.wa.edu.au/
# 14        NaN    NaN  https://www.det.wa.edu.au/schoolsonline/overvi...
# 15        NaN    NaN                  http://neerigenbrookps.wa.edu.au/
# 16        NaN    NaN                                                  -
# 17        NaN    NaN                 http://www.roleystonecc.wa.edu.au/
# 18        NaN    NaN                http://www.southernhills.wa.edu.au/
# 19        NaN    NaN                       http://www.xavier.wa.edu.au/
# 20        NaN    NaN  http://www.det.wa.edu.au/schoolsonline/overvie...
# 21        NaN    NaN                  http://www.willandraps.wa.edu.au/
# 22        NaN    NaN                    http://harrisdaleshs.wa.edu.au/
# 23        NaN    NaN             https://facebook.com/oreahaja.kitchen/
# 24        NaN    NaN            http://www.facebook.com/thesimplegrazer
# 25        NaN    NaN                                                  -
# 26        NaN    NaN                                                  -
# 27        NaN    NaN             https://www.armadalesoccerclub.com.au/
# 28        NaN    NaN                                                  -
# 29        NaN    NaN                      http://www.armadalegolf.club/
# 30        NaN    NaN                    https://www.armadalersl.com.au/
# 31        NaN    NaN                     https://www.dalehockey.org.au/
# 32        NaN    NaN            http://wallangarraadultriders.webs.com/
# 33        NaN    NaN  https://www.armadale.wa.gov.au/community-facil...
# 34        NaN    NaN                                                  -
# 35        NaN    NaN                                                  -
# 36        NaN    NaN               http://www.roleyfamilycentre.com.au/
# 37        NaN    NaN  https://www.armadale.wa.gov.au/community-facil...
# 38        NaN    NaN                                                  -
# 39        NaN    NaN                   http://kelmscottbulldogs.org.au/
# 40        NaN    NaN  https://www.armadale.wa.gov.au/community-facil...
# 41        NaN    NaN  https://www.armadale.wa.gov.au/community-facil...
# 42        NaN    NaN                                                  -
# 43        NaN    NaN          http://www.armadalelotterieshouse.com.au/
# 44        NaN    NaN                                                  -
# 45        NaN    NaN  https://www.armadale.wa.gov.au/community-facil...
# 46        NaN    NaN                     http://www.risenetwork.com.au/
# 47        NaN    NaN                                                  -
# 48        NaN    NaN  https://www.armadale.wa.gov.au/community-facil...
# 49        NaN    NaN                    https://www.proecclesia.com.au/
#
#    menu_(yes,_provided_on_website/no) children's_menu_provided_(yes/no)  \
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
# 5                                 NaN                               NaN
# 6                                 NaN                               NaN
# 7                                 NaN                               NaN
# 8                                 NaN                               NaN
# 9                                 NaN                               NaN
# 10                                NaN                               NaN
# 11                                NaN                               NaN
# 12                                NaN                               NaN
# 13                                NaN                               NaN
# 14                                NaN                               NaN
# 15                                NaN                               NaN
# 16                                NaN                               NaN
# 17                                NaN                               NaN
# 18                                NaN                               NaN
# 19                                NaN                               NaN
# 20                                NaN                               NaN
# 21                                NaN                               NaN
# 22                                NaN                               NaN
# 23                                NaN                               NaN
# 24                                NaN                               NaN
# 25                                NaN                               NaN
# 26                                NaN                               NaN
# 27                                NaN                               NaN
# 28                                NaN                               NaN
# 29                                NaN                               NaN
# 30                                NaN                               NaN
# 31                                NaN                               NaN
# 32                                NaN                               NaN
# 33                                NaN                               NaN
# 34                                NaN                               NaN
# 35                                NaN                               NaN
# 36                                NaN                               NaN
# 37                                NaN                               NaN
# 38                                NaN                               NaN
# 39                                NaN                               NaN
# 40                                NaN                               NaN
# 41                                NaN                               NaN
# 42                                NaN                               NaN
# 43                                NaN                               NaN
# 44                                NaN                               NaN
# 45                                NaN                               NaN
# 46                                NaN                               NaN
# 47                                NaN                               NaN
# 48                                NaN                               NaN
# 49                                NaN                               NaN
#
#                                         opening_hours  notes
# 1   ["Monday: 8:00 AM \u2013 4:00 PM","Tuesday: 8:...    NaN
# 2   ["Monday: 8:00 AM \u2013 4:00 PM","Tuesday: 8:...    NaN
# 3   ["Monday: 8:30 AM \u2013 4:00 PM","Tuesday: 8:...    NaN
# 4   ["Monday: Open 24 hours","Tuesday: Open 24 hou...    NaN
# 5   ["Monday: 8:00 AM \u2013 3:30 PM","Tuesday: 8:...    NaN
# 6   ["Monday: 8:30 AM \u2013 4:00 PM","Tuesday: 8:...    NaN
# 7                                                 "-"    NaN
# 8   ["Monday: 8:45 AM \u2013 2:55 PM","Tuesday: 8:...    NaN
# 9   ["Monday: 8:00 AM \u2013 4:00 PM","Tuesday: 8:...    NaN
# 10  ["Monday: 6:30 \u2013 8:30 AM, 2:30 \u2013 6:3...    NaN
# 11  ["Monday: 8:15 AM \u2013 3:30 PM","Tuesday: 8:...    NaN
# 12  ["Monday: 8:00 AM \u2013 4:00 PM","Tuesday: 8:...    NaN
# 13  ["Monday: 8:00 AM \u2013 3:30 PM","Tuesday: 8:...    NaN
# 14  ["Monday: Open 24 hours","Tuesday: Open 24 hou...    NaN
# 15  ["Monday: 8:00 AM \u2013 3:00 PM","Tuesday: 8:...    NaN
# 16                                                "-"    NaN
# 17  ["Monday: 9:00 AM \u2013 4:00 PM","Tuesday: Cl...    NaN
# 18  ["Monday: 8:00 AM \u2013 4:00 PM","Tuesday: 8:...    NaN
# 19  ["Monday: 8:15 AM \u2013 3:30 PM","Tuesday: 8:...    NaN
# 20                                                "-"    NaN
# 21  ["Monday: 8:00 AM \u2013 4:00 PM","Tuesday: 8:...    NaN
# 22  ["Monday: 8:40 AM \u2013 2:50 PM","Tuesday: 8:...    NaN
# 23  ["Monday: Closed","Tuesday: Closed","Wednesday...    NaN
# 24  ["Monday: 8:00 AM \u2013 9:00 PM","Tuesday: 8:...    NaN
# 25                                                "-"    NaN
# 26                                                "-"    NaN
# 27                                                "-"    NaN
# 28  ["Monday: 3:00 \u2013 10:00 PM","Tuesday: 3:00...    NaN
# 29  ["Monday: 6:30 AM \u2013 5:00 PM","Tuesday: 6:...    NaN
# 30  ["Monday: Closed","Tuesday: Closed","Wednesday...    NaN
# 31                                                "-"    NaN
# 32                                                "-"    NaN
# 33                                                "-"    NaN
# 34                                                "-"    NaN
# 35                                                "-"    NaN
# 36  ["Monday: 9:00 AM \u2013 3:00 PM","Tuesday: 9:...    NaN
# 37                                                "-"    NaN
# 38                                                "-"    NaN
# 39                                                "-"    NaN
# 40                                                "-"    NaN
# 41                                                "-"    NaN
# 42                                                "-"    NaN
# 43                                                "-"    NaN
# 44  ["Monday: 3:00 \u2013 8:30 PM","Tuesday: 3:00 ...    NaN
# 45                                                "-"    NaN
# 46                                                "-"    NaN
# 47  ["Monday: 6:00 PM \u2013 12:00 AM","Tuesday: 6...    NaN
# 48  ["Monday: 9:00 AM \u2013 4:00 PM","Tuesday: 9:...    NaN
# 49  ["Monday: 9:00 AM \u2013 4:30 PM","Tuesday: 9:...    NaN
#
# [49 rows x 25 columns]

# %%
armadale.to_excel(r'Matched_Armadale.xlsx', index = False)

# %%
armadale[armadale['classification_name'].isna()]
# Out:
#     local_government_area  business_id                    places_id  \
# 42      Armadale, City of          NaN  ChIJhy-02XOUMioRG0kaKRuCS5o
# 149     Armadale, City of          NaN  ChIJBZloGYyTMioRtL0B3BCToW8
# 164     Armadale, City of          NaN  ChIJgVgemteWMioRGCrzxz4xvCg
# 195     Armadale, City of          NaN  ChIJo-gtS5DrMioR_aTnpGvTJYo
#
#      collection_year                                business_name  \
# 42              2022  Riverside Park Pony Club - Palomino Reserve
# 149             2022                              Silva's Kitchen
# 164             2022   SN & A D'Orazio & Son - Poultry Processing
# 195             2022          Marshall's Western Australian Honey
#
#     temp_business_types classification_name category_1 sub_category_1  \
# 42       street_address                 NaN        NaN            NaN
# 149      street_address                 NaN        NaN            NaN
# 164      street_address                 NaN        NaN            NaN
# 195      street_address                 NaN        NaN            NaN
#
#     category_2  ...             original_lga_provided_address  \
# 42         NaN  ...  34 Palomino Place CHAMPION LAKES WA 6111
# 149        NaN  ...        17 Kingshurst Chase HAYNES WA 6112
# 164        NaN  ...        64 Taylor Road FORRESTDALE WA 6112
# 195        NaN  ...      213 Irymple Road KARRAGULLEN WA 6111
#
#                                      formatted_address  contact_1  contact_2  \
# 42   34 Palomino Pl, Champion Lakes WA 6111, Australia          -        NaN
# 149        17 Kingshurst Ch, Haynes WA 6112, Australia          -        NaN
# 164       64 Taylor Rd, Forrestdale WA 6112, Australia          -        NaN
# 195     213 Irymple Rd, Karragullen WA 6111, Australia          -        NaN
#
#      email website menu_(yes,_provided_on_website/no)  \
# 42     NaN       -                                NaN
# 149    NaN       -                                NaN
# 164    NaN       -                                NaN
# 195    NaN       -                                NaN
#
#     children's_menu_provided_(yes/no)  opening_hours  notes
# 42                                NaN            "-"    NaN
# 149                               NaN            "-"    NaN
# 164                               NaN            "-"    NaN
# 195                               NaN            "-"    NaN
#
# [4 rows x 25 columns]
